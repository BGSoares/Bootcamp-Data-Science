# %% [markdown]
# # **SPICED ACADEMY // WEEKS 11-12 // FINAL PROJECT**

# %%
import pandas as pd

# Plotting
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 5)

# %%
df = pd.read_csv('data/covid19_tweets.csv', parse_dates=['user_created','date'])

# %%
df.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description        user_created  \
# 0  wednesday addams as a disney princess keepin i... 2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth... 2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re... 2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ... 2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf... 2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
df['date'].agg(['min', 'max'])
# Out:
# min   2020-07-24 23:47:08
# max   2020-08-30 09:07:39
# Name: date, dtype: datetime64[ns]

# %%
# !ls data
# Out:
# archive.zip        covid19_tweets.csv multiTimeline.csv

# %%
trends = pd.read_csv('data/multiTimeline.csv', header=1, parse_dates=['Week'], index_col=['Week'])
trends['Moderna: (United States)'].replace('<1', 1, inplace=True)
trends = trends.astype({'Moderna: (United States)':'int64'})

# %%
trends[trends.index>'01-01-2020'].plot(title='Company Search Popularity & COVID-19 in US', ylabel='Search Popularity Index')
# Out:
# <AxesSubplot:title={'center':'Company Search Popularity & COVID-19 in US'}, xlabel='Week', ylabel='Search Popularity Index'>
